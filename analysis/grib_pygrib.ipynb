# %%
# conda install -c anaconda basemap ipykernel
# conda install -c conda-forge matplotlib pygrib

import pygrib
from matplotlib import pyplot as plt
from matplotlib import colors
import numpy as np

# %matplotlib inline

# %%
filename = './data/IDY35000.G3.pop-flds.slv.2022031512.000.surface.grib2'
file = pygrib.open(filename)

# %%
for grb in file:
    print(grb)
# Out:
# 1:10 metre wind direction:Degree true (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 202203151200
# 2:10 metre wind speed:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 202203151200
# 3:195:195 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 4:Mean wave direction:Degree true (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 5:Primary wave direction:Degree true (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 6:Primary wave mean period:s (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 7:Significant height of combined wind waves and swell:m (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 8:Direction of wind waves:Degree true (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 202203151200
# 9:Direction of swell waves:Degree true (instant):regular_ll:unknown:level 1 241:fcst time 0 hrs:from 202203151200
# ...

# %%
mean_wave_period = file.select(name='Mean wave period')[0]
mean_wave_period.keys()
# Out:
# ['globalDomain',
#  'GRIBEditionNumber',
#  'tablesVersionLatestOfficial',
#  'tablesVersionLatest',
#  'grib2divider',
#  'angleSubdivisions',
#  'missingValue',
#  'ieeeFloats',
#  'isHindcast',
#  'section0Length',
#  'identifier',
#  'discipline',
#  'editionNumber',
#  'totalLength',
#  'sectionNumber',
#  'section1Length',
#  'numberOfSection',
#  'centre',
#  'centreDescription',
#  'subCentre',
#  'tablesVersion',
#  'masterDir',
#  'localTablesVersion',
#  'significanceOfReferenceTime',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'second',
#  'dataDate',
#  'julianDay',
#  'dataTime',
#  'productionStatusOfProcessedData',
#  'typeOfProcessedData',
#  'md5Section1',
#  'selectStepTemplateInterval',
#  'selectStepTemplateInstant',
#  'stepType',
#  'is_chemical',
#  'is_chemical_distfn',
#  'is_chemical_srcsink',
#  'is_aerosol',
#  'is_aerosol_optical',
#  'setCalendarId',
#  'deleteCalendarId',
#  'sectionNumber',
#  'grib2LocalSectionPresent',
# ...

# %%
mean_wave_period.values
# Out:
# masked_array(
#   data=[[7.2, 7.2, 7.2, ..., 7.24, 7.24, 7.2],
#         [7.2, 7.2, 7.2, ..., 7.24, 7.24, 7.2],
#         [7.44, 7.44, 7.44, ..., 7.49, 7.49, 7.44],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=9999.0)

# %%
lats, lons = mean_wave_period.latlons()
lats.shape, lats.min(), lats.max(), lons.shape, lons.min(), lons.max()
# Out:
# ((1201, 2881), -75.0, 75.0, (1201, 2881), 0.0, 360.0)

# %%
mwp_specific, lats, lons = mean_wave_period.data(lat1=-75, lat2=-30, lon1=45, lon2=160)
mwp_specific
# Out:
# masked_array(
#   data=[[6.7, 6.68, 6.67, ..., 6.53, 6.54, 6.5600000000000005],
#         [6.73, 6.71, 6.7, ..., 6.51, 6.51, 6.53],
#         [6.7700000000000005, 6.75, 6.75, ..., 6.48, 6.49, 6.51],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=9999.0)
